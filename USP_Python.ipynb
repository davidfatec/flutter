# %% [markdown]
# <a href="https://colab.research.google.com/github/davidfatec/PythonEstudos/blob/main/USP_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PYTHON USP**

# %%
velocidadeMedia = 0
distancia = 450
tempo = 6
v= distancia / tempo
print(f'{v}km/h')
# Out:
# 75.0km/h

# %%
e = 0
m = 30
v = 10
e = (m*v**2)/2
print(e)
# Out:
# 1500.0

# %%
from math import sqrt
a = 2
b = 3
c = -3
delta = (b**2) - (4*a*c)
x1 = (-b + sqrt(delta)) / (2*a)
x2 = (-b - sqrt(delta)) / (2*a)
print(x1,x2)
# Out:
# 0.6861406616345072 -2.186140661634507

# %% [markdown]
# O terminal do python pode ser usado como calculadora, em matematica usamos parenteses, chaves e conchetes, em python utilizamos apenas parenteses e as ordens de precedencias ocorre nos parenteses mais internos.

# %% [markdown]
# **Variaveis** → é um pedacinho da memória do computador onde pode ser armazenado valores. Esses valores podem ser mudados conforme a programação do desenvolvedor
# ex:
#
# nome = 'David'
#
# idade = 42
#
# peso = 81

# %%
nome = 'David'
idade = 42
peso = 82.3
masculino = True

print(f'Nome: {nome}\nIdade: {idade}\nPeso: {peso}\nÉ homem: {masculino}')
# Out:
# Nome: David
# Idade: 42
# Peso: 82.3
# É homem: True

# %% [markdown]
# **SOFTWARE LIVRE →** Programas podem ser melhorados, modificados por varias pessoas e o conhecimento que está lá pode ser acessado por qualquer pessoa. Já nos softwares não livres não tem acesso ao conhecimento que está embutido, não pode ser compartilhado, nem copiado, pois está protegido por copyright.
#
# **Definição → atende 4 pré requisitos**
#
# Qualquer pessoa pode executar o programa
# Qualquer pessoa pode estudar e modifica
# Qualquer pessoa pode distribuir o programa
# Qualquer pessoa pode distribuir o que foi criado pela pessoa
#
# Melhor qualidade pois varias pessoas e empresas criam e modificam
#
# ex: Java, Ruby, Python, R → exemplos de software livre
#
# Outros → mySql, android, firefox

# %% [markdown]
# **TIPOS DE VARIAVEIS**
#
# str 'Variavel'
#
# float 2.0
#
# int   2
#
# boolean True or False

# %%
#tipos de variáveis
nome = "David"
idade = 42
altura = 1.73
vivo = True
print(type(nome))
print(type(idade))
print(type(altura))
print(type(vivo))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
temp = str(altura) #como foi convertida pra str podemos ler o tamanho da variavel
print(len(temp))
# Out:
# 4

# %% [markdown]
# **Entrada de dados comando 'input'**
#
# o input faz com que determinada variavel receba um valor
#
# input sempre retorna string
#
# float(input()) converte float
#
# int(input()) converte int

# %% [markdown]
# **Convertendo tipo de variável**

# %%
#nesse exemplo vamos tratar a virgula do padrão brasileiro pra ponto 
dinheiro = str(input('Digite o valor R$ ')).replace(',','.').strip()
dinheiro = float(dinheiro)
print(dinheiro)
# Out:
# Digite o valor R$ 55,33
# 55.33

# %%
def main():
    # a_str e b_str guardam strings
    a_str = input("Digite o primeiro numero: ")
    b_str = input("Digite o segundo numero: ")

    # a_int e b_int guardam inteiros
    a_int = int(a_str) # converte string/texto para inteiro
    b_int = int(b_str) # converte string/texto para inteiro

    # calcule a soma entre valores que são números inteiros
    soma = a_int + b_int

    # imprima a soma
    print("A soma de", a_int, "+", b_int, "eh igual a", soma)

main()
# Out:
# Digite o primeiro numero: 8
# Digite o segundo numero: 9
# A soma de 8 + 9 eh igual a 17

# %%
#exemplo: nesse programa a variável vai receber um temperatura
temperatura = float(input('Digite a temperatura em °F: '))
celsius = ((temperatura - 32)/9)*5
print(f'{celsius:.2f}')
# Out:
# Digite a temperatura em °F: 33
# 0.56

# %% [markdown]
# https://panda.ime.usp.br/aulasPython/static/aulasPython/aula02.html

# %% [markdown]
# **Exercício 2.1**
#
# Dados dois inteiros a e b, calcular a sua soma.
#
# Tentativa 0: execute o programa abaixo e veja o que acontece.

# %%
def main():
  a = 4
  b = 8
  soma = a+b
  print(soma)
main()
# Out:
# 12

# %% [markdown]
# **print()**
#
# A função print() é utilizada para o programa exibir mensagens. Por exemplo:
#
# print("Olá, mundo!")
#
# print("A soma é", soma)
#
# Escreve na tela do computador
#
# Olá, mundo!
#
# A soma é XXXX
#
# onde XXXX é o valor ao qual a variável soma se refere.
#
# Tentativa 1: execute o programa abaixo e veja o que acontece.
#
# Observe que o print() recebeu dois valores separados por vírgula:
# um string (entre aspas) e
# o nome de uma variável
# O string é impresso diretamente (pois esse é o seu valor) e, ao invés de imprimir o nome da variável soma, o print() exibe o valor ao qual a variável soma se refere, ou, dito mais simplesmente, o valor da variável soma.
#
# Mas e como imprimir os valores de a e b ao invés de seus nomes?
#
# Tentativa 2: execute o programa abaixo e veja o que acontece.

# %%
def main():
  a = 4
  b = 8
  soma = a+b
  print('A soma de',a,'+',b,'é igual a',soma)
main()
# Out:
# A soma de 4 + 8 é igual a 12

# %% [markdown]
# **O codigo abaixo tem uma função que recebe o numero e calcula seu fator**
#
# n vamos usar o numero 4 no exemplo abaixo.
#
# fat → 1
#
# i → 2
#
# enquanto
#
# 2 de i é menor que 4
#
# fat = 1 * 2 → 2
#
# i = 2 + 1 → 3
#
# 3 de i é menor que 4
#
# fat = 2 * 3 → 6
#
# i = 3 + 1 → 4
#
# 4 de i é menor ou igual 4
#
# fat = 6 * 4 → 24
#
# i = 4 + 1 → 5  → os sistema do while para aqui pois i se tornou maior que 4, o numero do exemplo.

# %%
def main():
    numero = int(input("Digite o valor de número: "))
    fat = 1 # inicia o valor do fatorial com 1
    i = 2 #i recebe valor de 2
    while i <= numero: #enquanto i for menor que o numero
        fat = fat*i  #o valor de fat que é 1 vai receber seu valor multiplicado por i
        i = i + 1 #o i recebe o incremento de 1

    print("O valor de %d! eh =" %numero, fat)

#--------------------------------------------
main()
# Out:
# Digite o valor de número: 4
# O valor de 4! eh = 24

# %% [markdown]
# **Valores booleanos** Matemático George Boole
#
# valores False or True
#
# 2 == 1+1 True
#
# 2 > 3 False
#
# **Operadores booleanos** and or not
#
# **and** → os dois resultados precisam ser verdadeiros
#
# x > 0 and x **2 > 25
#
# x == 0 False
#
# x == 25 False
#
# x == 17 False
#
# x == 26 True
#
# x == 10000 True
#
# x == -548 False
#
# **or** → pelo penos uma parte precisa ser verdadeira
#
# x > 0 or x **2 > 25
#
# x == 0 False
#
# x == 25 True
#
# x == 17 True
#
# x == 26 True
#
# x == 10000 True
#
# x == -548 False
#
# **not** → inverte o valor do booleano

# %%
#EXEMPLO and
#vou pra praia segunda se for feriado e se fizer sol 
feriado = True
sol = False
vouPraPraia = feriado and sol
print(vouPraPraia)
# Out:
# False

# %%
#EXEMPLO or
#vou pra praia segunda se for feriado ou se fizer sol 
feriado = True
sol = False
vouPraPraia = feriado or sol
print(vouPraPraia)
# Out:
# True

# %% [markdown]
# **ordem de precedencia**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Condicionais IF, ELSE, ELIF**
#
# if condição (True or False):
#
#      codigo.
#
# if condição (True or False):
#
#      codigo verdadeiro
# else:
#
#      codigo falso
#
# **if** condição (True or False):
#
#      codigo 1
#
# **elif** outra condição (True or False):
#
#      codigo 2
#
# **else:** se não atender as condições acima
#
#      codigo 3

# %%
#Faça um algoritmo que calcule a equação do segundo grau.
print('Sistema que resolve equação do segundo grau')
from math import sqrt
a = int(input('Digite o valor de a: '))
b = int(input('Digite o valor de b: '))
c = int(input('Digite o valor de c: '))
delta = (b**2) - (4*a*c)
if delta < 0:
  print("essa equação não possui raízes reais")
elif delta == 0:
  raiz2 = (-b - sqrt(delta)) / (2*a)
  print(f'a raiz desta equação é {raiz2}')
else:
    raiz1 = (-b + sqrt(delta)) / (2*a)
    raiz2 = (-b - sqrt(delta)) / (2*a)
    if raiz1 < raiz2:
        print(f'as raízes da equação são {raiz1} e {raiz2}')
    else:
        print(f'as raízes da equação são {raiz2} e {raiz1}')
# Out:
# Sistema que resolve equação do segundo grau
# Digite o valor de a: 5
# Digite o valor de b: 3
# Digite o valor de c: 5
# essa equação não possui raízes reais

# %%
#Faça um algoritmo que calcule a equação do segundo grau usando funções.
print('Sistema que resolve equação do segundo grau')
from math import sqrt
def delta(a,b,c):
  return (b**2) - (4*a*c)
def main():  
  a = int(input('Digite o valor de a: '))
  b = int(input('Digite o valor de b: '))
  c = int(input('Digite o valor de c: '))
  imprimir_raizes(a,b,c)
def imprimir_raizes(a,b,c):
  d = delta(a,b,c)
  if d < 0:
    print("essa equação não possui raízes reais")
  elif d == 0:
    raiz2 = (-b - sqrt(d)) / (2*a)
    print(f'a raiz desta equação é {raiz2}')
  else:
      raiz1 = (-b + sqrt(d)) / (2*a)
      raiz2 = (-b - sqrt(d)) / (2*a)
      if raiz1 < raiz2:
          print(f'as raízes da equação são {raiz1} e {raiz2}')
      else:
          print(f'as raízes da equação são {raiz2} e {raiz1}')
main()
# Out:
# Sistema que resolve equação do segundo grau
# Digite o valor de a: 7
# Digite o valor de b: 5
# Digite o valor de c: 8
# essa equação não possui raízes reais

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Dados um número inteiro n, n > 0, e uma sequência com n números inteiros, determinar quantos números da sequência são pares e quantos são ímpares**

# %%
sequencia = (1,2,3,4,5,8,8,2)
par = 0
impar = 0
for i in range(0,8):
    if sequencia[i] % 2 == 0:
        par+=1
    else:
        impar+=1
print('Par = ',par)
print('Impar = ',impar)
# Out:
# Par =  5
# Impar =  3

# %% [markdown]
# **Final da semana 3**
#
# https://panda.ime.usp.br/aulasPython/static/aulasPython/aula03.html#aula03_ex1_tentativa

# %% [markdown]
# **SEMANA 4**
#
# comando de repetição **WHILE**
#
# vamos imaginar que eu precise imprimir a potencia de 2 dez vezes, nao uso o comando print as 10 vezes, tem uma forma melhor utilizando o comando while.

# %%
cont = 0
while cont < 10:
  print(2 ** cont)
  cont+=1
print('Fim do programa')
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# Fim do programa

# %% [markdown]
# **Crie um programa que receba um numero digitado pelo usuário e mostre a soma desses numeros e encerre quando o usuario digitar 0**

# %%
soma = 0
numero = ' '
while numero != 0:
  numero = int(input('Digite um numero: '))
  soma+=numero
print(soma)
# Out:
# Digite um numero: 8
# Digite um numero: 9
# Digite um numero: 7
# Digite um numero: 8
# Digite um numero: 41
# Digite um numero: 20
# Digite um numero: 0
# 93

# %% [markdown]
# **Crie um programa que receba um numero e em seguida o numero de vezes que deseja somar esse numero**

# %%
soma = 0
numero = int(input("Digite um numero: "))
vezes = int(input("Digite um numero de vezes que quer somar o numero digitado: "))
cont = 1
while cont <= vezes:
  soma+=numero
  cont+=1
print(soma)
# Out:
# Digite um numero: 58
# Digite um numero de vezes que quer somar o numero digitado: 10
# 580

# %% [markdown]
# **Crie um programa que receba um numero digitado pelo usuário e mostre o produto desses numeros e encerre quando o usuario digitar 0**

# %%
produto = 1
numero = ' '
while numero != 0:
  numero = int(input('Digite um numero: '))
  if numero == 0:
    break
  produto = produto * numero
print(produto)
# Out:
# Digite um numero: 5
# Digite um numero: 8
# Digite um numero: 100
# Digite um numero: 0
# 4000

# %% [markdown]
# **Crie um programa que leia um numero e mostre a soma de todos os numeros que compoe o numero lido** exemplo 852 → 8 + 5 + 2 = 15

# %%
numero = int(input('Digite um numero '))
soma = 0
inteiro = numero
i=1
while i < inteiro:
  soma += inteiro % 10
  inteiro = inteiro // 10
  i+=1
print(f'A soma dos numeros que compoe o numero {numero} é {soma + inteiro}')
# Out:
# Digite um numero 14587
# A soma dos numeros que compoe o numero 14587 é 25

# %% [markdown]
# **VARIAVEIS BOOLEANAS**
#
# exemplo de um programa que funciona enquanto a seguencia numerica for crescente

# %%
crescente = True
primeiro = int(input('Digite o primeiro valor: '))
numero = 1
while crescente and numero != 0:
  numero = int(input('Digite o próximo numero: '))
  if numero < primeiro:
    crescente = False
  primeiro == numero
if crescente:
   print('A sequencia está em ordem crescente')    
else:
   print('A sequencia não está em ordem crescente')
# Out:
# Digite o primeiro valor: 1
# Digite o próximo numero: 2
# Digite o próximo numero: 2
# Digite o próximo numero: 3
# Digite o próximo numero: 2
# Digite o próximo numero: 2
# Digite o próximo numero: 2
# Digite o próximo numero: 1
# Digite o próximo numero: 2
# Digite o próximo numero: 21
# Digite o próximo numero: 2
# Digite o próximo numero: 0
# A sequencia não está em ordem crescente

# %%
meuCartao = int(input('Digite o numero do seu cartão: '))
cartaoLido = 1
cartaoEncontrado = False
while cartaoLido != 0 and not cartaoEncontrado:
  cartaoLido = int(input("Digite o numero do cartão de crédito: "))
  if cartaoLido == meuCartao:
    cartaoEncontrado = True
if cartaoEncontrado:
  print('Cartão válido')
else:
  print('Cartão inválido')
# Out:
# Digite o numero do seu cartão: 4545
# Digite o numero do cartão de crédito: 4444
# Digite o numero do cartão de crédito: 4685
# Digite o numero do cartão de crédito: 4545
# Cartão válido

# %% [markdown]
# **Faça um programa que receba um numero e diga se tem dois numeros adjacentes iguais**

# %%
numero = int(input('Digite um número: ')) #22445
num = numero
adj = False
i = 0 
Psobra = numero
Ssobra = 0
while i < numero:
  Psobra = numero % 10
  numero = numero // 10
  Ssobra = numero % 10
  if Psobra == Ssobra:
    adj = True
    break
  i+=1
if adj:
  print(f'O número {num} tem dois numeros adjacentes {Ssobra}{Psobra}')
else:
  print(f'O número {num} não possui números adjacentes')
# Out:
# Digite um número: 8965788337
# O número 8965788337 tem dois numeros adjacentes 33

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **AVALIAÇÃO 2**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Tarefa de programação: Lista de exercicios 3**
#
# escreva um programa que receba um número natural na entrada e imprima seu fatorial na saida

# %%
numero = int(input('Digite o valor de n: '))
fatorial = 1
cont = numero
while cont > 0:
  fatorial = fatorial * cont
  cont-=1
print(fatorial)
# Out:
# Digite um numero: 0
# 1

# %% [markdown]
# **Receba um número inteiro positivo na entrada e imprima n primeiros numeros impares naturais**

# %%
n = int(input('Digite o valor de n: '))
cont = 0
while cont < n:
  print(2*cont + 1)
  cont+=1
# Out:
# Digite o valor de n: 7
# 1
# 3
# 5
# 7
# 9
# 11
# 13

# %% [markdown]
# **Escreva um programa que um número inteiro na entrada, calcule e imprima a soma dos digitos deste numero na saida**

# %%
numero = int(input('Digite um número inteiro: '))
soma = 0
inteiro = numero
i=1
while i < inteiro:
  soma += inteiro % 10
  inteiro = inteiro // 10
  i+=1
print(soma + inteiro)
# Out:
# Digite um número inteiro: 123
# 6

# %% [markdown]
# **SEMANA 5 → FUNÇÕES**
#
# funções são uteis porque podemos com elas agrupar pequenas partes dos códigos.
#
# def → palavra reservada de python que indica uma função;

# %%
#funções com parametros 
def soma(x,y):
  return x + y
def subtracao(x,y):
  return x - y  
def multiplicacao(x,y):
  return x * y 
def divisao(x,y):
  return x / y  


x = int(input('Digite um número: '))
y = int(input('Digite outro número: '))
print(soma(x,y))
print(subtracao(x,y))
print(multiplicacao(x,y))
print(divisao(x,y))
# Out:
# Digite um número: 8
# Digite outro número: 4
# 12
# 4
# 32
# 2.0

# %%
#funçoes sem parametros
bairro = input('Digite o nome do seu bairro: ')
def nome_bairro():
  return bairro
print(nome_bairro())
# Out:
# Digite o nome do seu bairro:

# %%
#funções sem retorno
velocidade=int(input('Velocidade capturada pelo radar: '))
maxima = 120
def multa():
  if velocidade > maxima:
    print(f'Você foi multado, sua velocidade {velocidade}, Maximo permitido {maxima} ')
multa()
# Out:
# Velocidade capturada pelo radar: 125
# Você foi multado, sua velocidade 125, Maximo permitido 120

# %% [markdown]
# **Coeficiente binomial**

# %%
def fatorial(numero):
  fat = 1
  while numero > 1:
     fat = fat * numero
     numero-=1
  return fat

def numeroBinomial(n,k):
   return fatorial(n) / ((fatorial(k)) * (fatorial(n - k)))

n = int(input('Digite o valor de n: ')) 
k = int(input('Digite o valor de k: '))
print(numeroBinomial(n,k))
# Out:
# Digite o valor de n: 4
# Digite o valor de k: 2
# 6.0

# %% [markdown]
# **Reorganize o programa feito para calculo de uma equação do segundo grau, utilize funções.**

# %%
print('Sistema que resolve equação do segundo grau')
from math import sqrt
a = int(input('Digite o valor de a: '))
b = int(input('Digite o valor de b: '))
c = int(input('Digite o valor de c: '))
delta = (b**2) - (4*a*c)
def raiz1():
  return (-b + sqrt(delta)) / (2*a)
def raiz2():
  return (-b - sqrt(delta)) / (2*a)  
if delta < 0:
  print("essa equação não possui raízes reais")
elif delta == 0:
  print(f'a raiz desta equação é {raiz2()}')
else:
    if raiz1() < raiz2():
        print(f'as raízes da equação são {raiz1()} e {raiz2()}')
    else:
        print(f'as raízes da equação são {raiz2()} e {raiz1()}')
# Out:
# Sistema que resolve equação do segundo grau
# Digite o valor de a: 2
# Digite o valor de b: 1
# Digite o valor de c: -3
# as raízes da equação são -1.5 e 1.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Introdução ao pytest**
#
# por que testar?
#
# -Seres humanos erram
#
# -Programas contém erros (bugs)
#
#    → Sintaxe
#
#    → Lógica
#
# -Software robusto deve conter o minimo possível de erros
#
# -Bugs podem causar catástrofes
#
# -Bugs podem causar desconforto
#    → E fazer com que seu cliente abandone seu produto
#
# **Como testar**
#
# -Testes manuais
#    → Cansativo
#
#    → Vai testar apenas alguns casos
#
#    → Vai testar apenas algumas vezes
#
# -Testes automatizados
#
#    → Bateria de testes que cobre o máximo possível do seu código.
#
#    → Executada rotineiramente várias vezes por dia.
#
# **Arcabouços de testes automatizados**
#
# - Instale em docs.pytest.org
#
# -Considera que arquivos do tipo test_*.py e *_test.py são arquivos de teste
#
# -Executa funções e métodos do tipo test_*
#
# -Considera classes do tipo Test*
#
# **Em suma**
#
# -Pense cuidadosamente nos casos em que seu programa pode falhar
#
# -pense nos diferentes tipos de entrada que exercitam caminhos diferentes no seu programa
#
# -Pense nos casos diferentes do seu código.
#
# -Escreva testes automatizados para todos esse casos.

# %%
def func(x):
  return x + 2

def test_answer():
  assert func(3) == 3

# %% [markdown]
# **Exercício 1 - Máximo**
#
# Escreva a função maximo que recebe 2 números inteiros como parâmetro e devolve o maior deles.

# %%
def maximo(x,y):
  maior = x
  if x < y:
    maior = y
  return maior
maximo(0,2)
# Out:
# 2

# %% [markdown]
# **Exercício 2 - Primos**
#
# Escreva a função maior_primo que recebe um número inteiro maior ou igual a 2 como parâmetro e devolve o maior número primo menor ou igual ao número passado à função

# %%
def éPrimo(k):
  divisor = 2
  if k == 2:
    return True
  while k % divisor != 0 and divisor <= k/2:
    divisor +=1
  if k % divisor == 0:
    return False
  else:
    return True      
def maior_primo(x):
  maior = 0
  cont = 2
  while cont <= x:
    if éPrimo(cont) == True:
       maior = cont
    cont+=1
  return maior
maior_primo(100)
# Out:
# 97

# %% [markdown]
# **Exercício 3 - Vogais**
#
# Escreva a função vogal que recebe um único caractere como parâmetro e devolve True se ele for uma vogal e False se for uma consoante.

# %%
def vogal(x):
  return x in 'aAeEiIoOuU'  
vogal('e')
# Out:
# True

# %% [markdown]
# **Exercício 1 - FizzBuzz**
#
# Escreva a função fizzbuzz que recebe como parâmetro um número inteiro e devolve
#
# 'Fizz' se o número for divisível por 3 e não for divisível por 5;
#
# 'Buzz' se o número for divisível por 5 e não for divisível por 3;
#
# 'FizzBuzz' se o número for divisível por 3 e por 5;
#
# Caso o número não seja divisível 3 e também não seja divisível por 5, ela deve devolver o número recebido como parâmetro.

# %%
def fizzbuzz(x):
  if x % 3 == 0 and x % 5 != 0:
    return 'Fizz'
  elif x % 5 == 0 and x % 3 != 0:
    return 'Buzz'
  elif x % 3 == 0 and x % 5 == 0:
    return 'FizzBuzz'  
  else:
    return x
fizzbuzz(10)
# Out:
# 'Buzz'

# %% [markdown]
# **Exercício 2 - Máximo com 3 parâmetros**
#
# Reescreva a função 'maximo' do outro exercício, que devolve o maior valor dentre dois inteiros recebidos, para que ela passe a receber 3 valores inteiros como parâmetros e devolva o maior dentre eles.

# %%
def maximo(x,y,z):
  maior = x
  if y > x and y > z:
    maior = y
  elif z > x and z > y:
    maior = z
  return maior
maximo(-15,8,-9)
# Out:
# 8

# %% [markdown]
# Funções: https://panda.ime.usp.br/aulasPython/static/aulasPython/aula06.html

# %%
def fatorial(x):
   fat = 1
   n = x
   cont = 1
   while cont <= n:
        fat = fat*x
        cont+=1
        x-=1
   return fat
fatorial(5) 
def combinacao(m,n):
  return fatorial(m)/(fatorial(m-n)*fatorial(n))
combinacao(4,6)
# Out:
# 0.03333333333333333

# %% [markdown]
# **Prova semana 6**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Jogo do NIM**

# %%
def computador_escolhe_jogada(n, m):
    computadorTira = 1
    while computadorTira != m:
        if (n - computadorTira) % (m+1) == 0:
            return computadorTira
        else:
            computadorTira += 1
    return computadorTira

def usuario_escolhe_jogada(n, m):
    jogadaValida = False
    while not jogadaValida:
        jogadorTira = int(input('\nQuantas peças você vai tirar? '))
        if jogadorTira > m or jogadorTira < 1:
            print('\nOops! Jogada inválida! Tente de novo.')
        else:
            jogadaValida = True
    return jogadorTira

def campeonato():
    numeroRodada = 1
    while numeroRodada <= 3:
        print('\n**** Rodada', numeroRodada, '****')
        partida()
        numeroRodada += 1
    print('\n**** Final do campeonato! ***')
    print('\nPlacar: Você 0 X 3 Computador')

def partida():
    n = int(input('\nQuantas peças? '))
    m = int(input('Limite de peças por jogada? '))
    vezDoPC = False
    if n % (m+1) == 0:
        print('\nVoce começa!')
    else:
        print('\nComputador começa!')
        vezDoPC = True
    while n > 0:
        if vezDoPC:
            computadorTira = computador_escolhe_jogada(n, m)
            n = n - computadorTira
            if computadorTira == 1:
                print('\nO computador tirou uma peça')
            else:
                print('\nO computador tirou', computadorTira, 'peças')
            vezDoPC = False
        else:
            jogadorTira = usuario_escolhe_jogada(n, m)
            n = n - jogadorTira
            if jogadorTira == 1:
                print('Você tirou uma peça')
            else:
                print('Você tirou', jogadorTira, 'peças')
            vezDoPC = True
        if n == 1:
            print('Agora resta apenas uma peça no tabuleiro.')
        else:
            if n != 0:
                print('Agora restam,', n, 'peças no tabuleiro.')
    print('Fim do jogo! O computador ganhou!')
print('Bem-vindo ao jogo do NIM! Escolha:')
print('\n1 - para jogar uma partida isolada')
tipoDePartida = int(input('2 - para jogar um campeonato '))
if tipoDePartida == 2:
    print('\nVoce escolheu um campeonato!')
    campeonato()
else:
    if tipoDePartida == 1:
        partida()
# Out:
# Bem-vindo ao jogo do NIM! Escolha:
#
# 1 - para jogar uma partida isolada
# 2 - para jogar um campeonato 1
#
# Quantas peças? 53
# Limite de peças por jogada? 3
#
# Computador começa!
#
# O computador tirou uma peça
# Agora restam, 52 peças no tabuleiro.
#
# Quantas peças você vai tirar? 3
# Você tirou 3 peças
# Agora restam, 49 peças no tabuleiro.
#
# O computador tirou uma peça
# Agora restam, 48 peças no tabuleiro.
#
# Quantas peças você vai tirar? 2
# Você tirou 2 peças
# Agora restam, 46 peças no tabuleiro.
#
# O computador tirou 2 peças
# Agora restam, 44 peças no tabuleiro.
#
# Quantas peças você vai tirar? 3
# Você tirou 3 peças
# Agora restam, 41 peças no tabuleiro.
#
# O computador tirou uma peça
# Agora restam, 40 peças no tabuleiro.
#
# Quantas peças você vai tirar? 5
#
# Oops! Jogada inválida! Tente de novo.
#
# Quantas peças você vai tirar? 3
# Você tirou 3 peças
# Agora restam, 37 peças no tabuleiro.
#
# O computador tirou uma peça
# ...

# %% [markdown]
# **SEMANA 7**
#
# **Repetições encaixadas**
#
# while condicao:
#
#     while condicao:
#
#        comando

# %%
#exemplo tabuada com while
linha = 1
coluna = 1
cont = 0
while linha <= 10:
  while coluna <= 10:
    print(f'{coluna} x {linha:2d} = {linha * coluna:3d}', end="\t")
    coluna = coluna + 1
  linha = linha + 1
  cont+=1
  print()
  coluna = 1
# Out:
# 1 x  1 =   1	2 x  1 =   2	3 x  1 =   3	4 x  1 =   4	5 x  1 =   5	6 x  1 =   6	7 x  1 =   7	8 x  1 =   8	9 x  1 =   9	10 x  1 =  10
# 1 x  2 =   2	2 x  2 =   4	3 x  2 =   6	4 x  2 =   8	5 x  2 =  10	6 x  2 =  12	7 x  2 =  14	8 x  2 =  16	9 x  2 =  18	10 x  2 =  20
# 1 x  3 =   3	2 x  3 =   6	3 x  3 =   9	4 x  3 =  12	5 x  3 =  15	6 x  3 =  18	7 x  3 =  21	8 x  3 =  24	9 x  3 =  27	10 x  3 =  30
# 1 x  4 =   4	2 x  4 =   8	3 x  4 =  12	4 x  4 =  16	5 x  4 =  20	6 x  4 =  24	7 x  4 =  28	8 x  4 =  32	9 x  4 =  36	10 x  4 =  40
# 1 x  5 =   5	2 x  5 =  10	3 x  5 =  15	4 x  5 =  20	5 x  5 =  25	6 x  5 =  30	7 x  5 =  35	8 x  5 =  40	9 x  5 =  45	10 x  5 =  50
# 1 x  6 =   6	2 x  6 =  12	3 x  6 =  18	4 x  6 =  24	5 x  6 =  30	6 x  6 =  36	7 x  6 =  42	8 x  6 =  48	9 x  6 =  54	10 x  6 =  60
# 1 x  7 =   7	2 x  7 =  14	3 x  7 =  21	4 x  7 =  28	5 x  7 =  35	6 x  7 =  42	7 x  7 =  49	8 x  7 =  56	9 x  7 =  63	10 x  7 =  70
# ...

# %% [markdown]
# **Construa um programa que receba vários números digitados pelo usuário e mostre o fatorial desse número**

# %%
print('Digite um número para que o fatorial seja exibido [-1 pra sair do sistema]')
numero = ' '
fat = 1
while numero != -1:
  numero = int(input('Digite um número: '))
  if numero < 0:
    print('Nº negativo acionado, saindo....')
    break
  else:
    while numero > 0:
      fat = fat * numero
      numero-=1  
    print(fat)
    fat = 1

# %%
print('Digite um número para que o fatorial seja exibido [-1 pra sair do sistema]')

def fatorial(numero):
      fat = 1
      while numero > 0:
        fat = fat * numero
        numero-=1  
      print(fat)
      fat = 1

numero = int(input('Digite um número: '))
while numero != -1:
   fatorial(numero)
   numero=-1
   numero = int(input('Digite um número: '))
# Out:
# Digite um número para que o fatorial seja exibido [-1 pra sair do sistema]
# Digite um número: 5
# 120
# Digite um número: -1

# %% [markdown]
# **Dado um número inteiro n, n>1, imprimir sua decomposição em fatores primos, indicando tambem a multiplicidade de cada fator**

# %%
n = int(input('Digite um numero maior que 1: '))
fator = 2
multiplicidade = 0
while n > 1:
    while n % fator == 0:
      multiplicidade += 1 
      n = n / fator
    if multiplicidade > 0:  
      print(f'Fator: {fator}\nMultiplicidade: {multiplicidade}')
    fator += 1
    multiplicidade = 0
# Out:
# Digite um numero maior que 1: 65536
# Fator: 2
# Multiplicidade: 16

# %% [markdown]
# **Dado um numero positivo digitado pelo usuario diga se é primo ou não**

# %%
def primo (x):
  fator = 2
  while x % fator !=0 and fator <= x/2:
    fator+=1
  if x % fator == 0 and x != 2:
    return False
  else:
    return True

n = int(input('Digite um número inteiro: '))
while n > 0:
  if primo(n):
    print(f"O número {n} é primo")
  else:
    print(f"O número {n} não é primo") 
  n = int(input('Digite um número inteiro: '))  
if n < 0:
  print('Sistema encerrado')
# Out:
# Digite um número inteiro: 2
# O número 2 é primo
# Digite um número inteiro: -1
# Sistema encerrado

# %% [markdown]
# **Exercício 1**
# Escreva um programa que recebe como entradas (utilize a função input) dois números inteiros correspondentes à largura e à altura de um retângulo, respectivamente. O programa deve imprimir, usando repetições encaixadas (laços aninhados), uma cadeia de caracteres que represente o retângulo informado com caracteres '#' na saída.

# %%
largura = int(input('digite a largura: '))
altura = int(input('digite a altura: '))   
while  altura > 0:
   aux = 0
   while aux < largura:
     print('#',end="")
     aux+=1  
   altura-=1
   print()
# Out:
# digite a largura: 5
# digite a altura: 2
# #####
# #####

# %% [markdown]
# **Exercício 2**
# Refaça o exercício 1 imprimindo os retângulos sem preenchimento, de forma que os caracteres que não estiverem na borda do retângulo sejam espaços.
#
# Por exemplo:

# %%
largura = int(input('digite a largura: '))
altura = int(input('digite a altura: '))   
a = altura
l = largura
while  altura > 0:
   aux = 0
   while aux < largura:
     if altura == a or aux == l-1 or altura == 1 or aux == 0:
        print('#',end="")
     else:
        print(' ',end="")   
     aux+=1  
   altura-=1
   print()
# Out:
# digite a largura: 5
# digite a altura: 4
# #####
# #   #
# #   #
# #####

# %% [markdown]
# *Exercício 1 - Primos*
# Escreva a função n_primos que recebe como argumento um número inteiro maior ou igual a 2 como parâmetro e devolve a quantidade de números primos que existem entre 2 e n (incluindo 2 e, se for o caso, n).

# %%
def primo(x):
    fator = 2
    while x % fator !=0 and fator <= x/2:
      fator+=1
    if x % fator == 0 and x != 2:
      return False
    else:
      return True
      
def n_primos(x):
  inicio = 2
  total = 0
  fator = 2
  while inicio <= x:
    if primo(inicio):
      total+=1
    inicio+=1
  return total    
n_primos(121)
# Out:
# 30

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import sqrt
def é_hipotenusa(n):
  i = 1
  while(i <= n):
    j = 1
    while j <= n:
      a = i
      b = j
      c = int(sqrt((a ** 2)+(b**2)))
      if(c > a) and (c > b) and (c < (a + b)):
        if((a ** 2) + (b ** 2) == c ** 2 ):
          if (c == n):
            return c
      j+=1      
    i+=1
  return 0

def soma_hipotenusas(n):  
  soma = 0
  anterior = 0
  i = 1
  for i in range(1,n+1):
    resultado = é_hipotenusa(i)
    if resultado > anterior:
       anterior = resultado
       soma+=resultado
  return soma

soma_hipotenusas(25)
# Out:
# 105
